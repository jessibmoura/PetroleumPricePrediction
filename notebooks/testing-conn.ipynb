# %% [markdown]
# ## Testing connection to the API

# %%
import requests

# %%
api_key = "sZW7oxzsj3eAfdDEsUy8eFUTd4MSMajQNE2fF8OJ"

# %%
url = f"https://api.eia.gov/v2/petroleum/pri/spt/data/?api_key={api_key}&frequency=daily&data[0]=value&start=2021-01-01&end=2024-09-30&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000"

# %%
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'response': {'warnings': [{'warning': 'incomplete return',
#     'description': 'The API can only return 5000 rows in JSON format.  Please consider constraining your request with facet, start, or end, or using offset to paginate results.'}],
#   'total': '10257',
#   'dateFormat': 'YYYY-MM-DD',
#   'frequency': 'daily',
#   'data': [{'period': '2024-09-30',
#     'duoarea': 'RGC',
#     'area-name': 'NA',
#     'product': 'EPD2DXL0',
#     'product-name': 'No 2 Diesel Low Sulfur (0-15 ppm)',
#     'process': 'PF4',
#     'process-name': 'Spot Price FOB',
#     'series': 'EER_EPD2DXL0_PF4_RGC_DPG',
#     'series-description': 'U.S. Gulf Coast Ultra-Low Sulfur No 2 Diesel Spot Price (Dollars per Gallon)',
#     'value': '2.067',
#     'units': '$/GAL'},
#    {'period': '2024-09-30',
#     'duoarea': 'ZEU',
#     'area-name': 'NA',
#     'product': 'EPCBRENT',
#     'product-name': 'UK Brent Crude Oil',
#     'process': 'PF4',
#     'process-name': 'Spot Price FOB',
# ...
