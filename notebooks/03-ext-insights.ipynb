# %% [markdown]
# Experimenting different external insights data

# %%
import pandas as pd

# %%
df = pd.read_excel("../data/external/Statistical Review of World Energy Data.xlsx",
                    sheet_name="Oil Production - barrels",
                    header=2,
                    skipfooter=11)

# %%
df.head()
# Out:
#   Thousand barrels daily       1965       1966       1967       1968  \
# 0                    NaN        NaN        NaN        NaN        NaN
# 1                 Canada    920.000   1012.000   1106.000   1194.000
# 2                 Mexico    362.000    370.000    411.000    439.000
# 3                     US   9014.148   9579.241  10219.252  10599.743
# 4    Total North America  10296.148  10961.241  11736.252  12232.743
#
#         1969       1970       1971       1972       1973  ...          2017  \
# 0        NaN        NaN        NaN        NaN        NaN  ...           NaN
# 1   1306.000   1473.000   1582.000   1829.000   2114.000  ...   4813.033351
# 2    461.000    487.000    486.000    506.000    525.000  ...   2224.150178
# 3  10827.674  11296.849  11155.778  11184.896  10945.953  ...  13140.416658
# 4  12594.674  13256.849  13223.778  13519.896  13584.953  ...  20177.600187
#
#            2018          2019          2020          2021          2022  \
# ...

# %%
df.dropna(how='all',inplace=True)

# %%
df
# Out:
#        Thousand barrels daily          1965          1966          1967  \
# 1                      Canada    920.000000   1012.000000   1106.000000
# 2                      Mexico    362.000000    370.000000    411.000000
# 3                          US   9014.148000   9579.241000  10219.252000
# 4         Total North America  10296.148000  10961.241000  11736.252000
# 6                   Argentina    275.673973    292.864110    318.631233
# ..                        ...           ...           ...           ...
# 70         Total Asia Pacific    898.587836   1002.149616   1062.737288
# 72                Total World  31791.906986  34560.929416  37103.661353
# 73             of which: OECD  11018.182082  11677.425663  12464.862559
# 74                   Non-OECD  20773.724904  22883.503753  24638.798795
# 75                       OPEC  13700.653096  15110.985589  16111.730466
#
#             1968          1969          1970          1971          1972  \
# ...

# %%
df[df["Thousand barrels daily"] == "Total World"]
# Out:
#    Thousand barrels daily          1965          1966          1967  \
# 72            Total World  31791.906986  34560.929416  37103.661353
#
#             1968          1969          1970          1971          1972  \
# 72  40418.298858  43648.661455  48074.783538  50785.244492  53553.865181
#
#             1973  ...          2017          2018          2019          2020  \
# 72  58551.798401  ...  92587.764724  95001.699881  95172.303743  88928.244437
#
#             2021          2022          2023    2023.1   2013-23  2023.2
# 72  90282.155029  94291.826885  96376.064703  0.022104  0.010786     1.0
#
# [1 rows x 63 columns]

# %%
total_oil_consumption_globally = df[df["Thousand barrels daily"] == "Total World"]

# %%
total_oil_consumption_globally
# Out:
#    Thousand barrels daily          1965          1966          1967  \
# 72            Total World  31791.906986  34560.929416  37103.661353
#
#             1968          1969          1970          1971          1972  \
# 72  40418.298858  43648.661455  48074.783538  50785.244492  53553.865181
#
#             1973  ...          2017          2018          2019          2020  \
# 72  58551.798401  ...  92587.764724  95001.699881  95172.303743  88928.244437
#
#             2021          2022          2023    2023.1   2013-23  2023.2
# 72  90282.155029  94291.826885  96376.064703  0.022104  0.010786     1.0
#
# [1 rows x 63 columns]

# %%
total_oil_consumption_globally = total_oil_consumption_globally[["Thousand barrels daily",2020,2021,2022,2023]]

# %%
total_oil_consumption_globally
# Out:
#    Thousand barrels daily          2020          2021          2022  \
# 72            Total World  88928.244437  90282.155029  94291.826885
#
#             2023
# 72  96376.064703

# %%
total_oil_consumption_globally.to_csv("../data/processed/total_oil_consumption_globally.csv", index=False)
