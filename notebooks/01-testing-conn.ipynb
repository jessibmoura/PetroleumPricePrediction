# %% [markdown]
# ## Testing connection to the API

# %%
import requests

# %%
api_key = "sZW7oxzsj3eAfdDEsUy8eFUTd4MSMajQNE2fF8OJ"

# %%
url = f"https://api.eia.gov/v2/petroleum/pri/spt/data/?api_key={api_key}&frequency=daily&data[0]=value&start=2023-01-01&end=2023-12-31&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000"

# %%
response = requests.get(url)

# %%
response.status_code == 200
# Out:
# True

# %%
response.json()
# Out:
# {'response': {'total': '2730',
#   'dateFormat': 'YYYY-MM-DD',
#   'frequency': 'daily',
#   'data': [{'period': '2023-12-29',
#     'duoarea': 'YCUOK',
#     'area-name': 'NA',
#     'product': 'EPCWTI',
#     'product-name': 'WTI Crude Oil',
#     'process': 'PF4',
#     'process-name': 'Spot Price FOB',
#     'series': 'RWTC',
#     'series-description': 'Cushing, OK WTI Spot Price FOB (Dollars per Barrel)',
#     'value': '71.89',
#     'units': '$/BBL'},
#    {'period': '2023-12-29',
#     'duoarea': 'ZEU',
#     'area-name': 'NA',
#     'product': 'EPCBRENT',
#     'product-name': 'UK Brent Crude Oil',
#     'process': 'PF4',
#     'process-name': 'Spot Price FOB',
#     'series': 'RBRTE',
#     'series-description': 'Europe Brent Spot Price FOB (Dollars per Barrel)',
#     'value': '77.69',
#     'units': '$/BBL'},
#    {'period': '2023-12-29',
#     'duoarea': 'RGC',
#     'area-name': 'NA',
#     'product': 'EPJK',
#     'product-name': 'Kerosene-Type Jet Fuel',
# ...
